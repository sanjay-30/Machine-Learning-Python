# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('olympics.csv')
df.shape
# Out:
# (156, 17)

# %%
df.head()
# Out:
#     countries  ioc_code   summer_participations summer_gold  summer_silver  \
# 0  Afghanistan     (AFG)                     15           0              0
# 1      Algeria     (ALG)                     14           5              4
# 2    Argentina     (ARG)                     25          21             26
# 3      Armenia     (ARM)                      7           2              8
# 4  Australasia     (ANZ)                      2           3              4
#
#    summer_bronze summer_total  winter_participations  winter_gold  \
# 0              2            2                      0            0
# 1              8           17                      3            0
# 2             30           77                     20            0
# 3              8           18                      8            0
# 4              5           12                      0            0
#
#    winter_silver  winter_bronze  winter_total  total_participation total_gold  \
# ...

# %%
df.tail()
# Out:
#                             countries  ioc_code   summer_participations  \
# 151                             Zambia     (ZAM)                     14
# 152                           Zimbabwe     (ZIM)                     14
# 153       Independent Olympic Athletes     (IOA)                      3
# 154  Independent Olympic Participants      (IOP)                      1
# 155                        Mixed Team      (ZZX)                      3
#
#     summer_gold  summer_silver  summer_bronze summer_total  \
# 151           0              1              1            2
# 152           3              4              1            8
# 153           1              0              1            2
# 154           0              1              2            3
# 155          11              6              8           25
#
#      winter_participations  winter_gold  winter_silver  winter_bronze  \
# 151                      0            0              0              0
# ...

# %%
#check null

df.isnull().sum()
# Out:
# countries                0
# ioc_code                 0
# summer_participations    0
# summer_gold              0
# summer_silver            0
# summer_bronze            0
# summer_total             0
# winter_participations    0
# winter_gold              0
# winter_silver            0
# winter_bronze            0
# winter_total             0
# total_participation      0
# total_gold               0
# total_silver             0
# total_bronze             0
# total_total              0
# dtype: int64

# %%
df.describe().transpose()
# Out:
#                        count       mean         std  min    25%   50%    75%  \
# summer_participations  156.0  14.673077    7.432417  0.0   9.75  15.0  19.00
# summer_silver          156.0  34.782051   86.085726  0.0   1.00   5.0  29.25
# summer_bronze          156.0  37.775641   83.157105  0.0   1.00   6.0  31.25
# winter_participations  156.0   7.314103    7.900024  0.0   0.00   4.5  11.00
# winter_gold            156.0   7.506410   22.232640  0.0   0.00   0.0   1.00
# winter_silver          156.0   7.487179   21.431808  0.0   0.00   0.0   2.00
# winter_bronze          156.0   7.442308   20.126773  0.0   0.00   0.0   2.00
# winter_total           156.0  22.435897   63.293498  0.0   0.00   0.0   6.00
# total_participation    156.0  21.987179   13.948286  1.0  13.00  17.0  29.00
# total_silver           156.0  42.269231  101.547405  0.0   1.00   5.0  33.50
# total_bronze           156.0  45.217949   97.571102  0.0   1.00   7.5  37.00
#
#                          max
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   countries              156 non-null    object
#  1   ioc_code               156 non-null    object
#  2   summer_participations  156 non-null    int64
#  3   summer_gold            156 non-null    object
#  4   summer_silver          156 non-null    int64
#  5   summer_bronze          156 non-null    int64
#  6   summer_total           156 non-null    object
#  7   winter_participations  156 non-null    int64
#  8   winter_gold            156 non-null    int64
#  9   winter_silver          156 non-null    int64
#  10  winter_bronze          156 non-null    int64
#  11  winter_total           156 non-null    int64
#  12  total_participation    156 non-null    int64
#  13  total_gold             156 non-null    object
#  14  total_silver           156 non-null    int64
# ...

# %%
df.columns
# Out:
# Index(['countries ', 'ioc_code ', 'summer_participations', 'summer_gold',
#        'summer_silver', 'summer_bronze', 'summer_total',
#        'winter_participations', 'winter_gold', 'winter_silver',
#        'winter_bronze', 'winter_total', 'total_participation', 'total_gold',
#        'total_silver', 'total_bronze', 'total_total '],
#       dtype='object')

# %%
df.columns.unique
# Out:
# <bound method Index.unique of Index(['countries ', 'ioc_code ', 'summer_participations', 'summer_gold',
#        'summer_silver', 'summer_bronze', 'summer_total',
#        'winter_participations', 'winter_gold', 'winter_silver',
#        'winter_bronze', 'winter_total', 'total_participation', 'total_gold',
#        'total_silver', 'total_bronze', 'total_total '],
#       dtype='object')>

# %%
df.head(10)
# Out:
#     countries  ioc_code   summer_participations summer_gold  summer_silver  \
# 0  Afghanistan     (AFG)                     15           0              0
# 1      Algeria     (ALG)                     14           5              4
# 2    Argentina     (ARG)                     25          21             26
# 3      Armenia     (ARM)                      7           2              8
# 4  Australasia     (ANZ)                      2           3              4
# 5    Australia     (AUS)                     27         164            173
# 6      Austria     (AUT)                     28          20             35
# 7   Azerbaijan     (AZE)                      7           7             14
# 8      Bahamas     (BAH)                     17           8              2
# 9      Bahrain     (BRN)                     10           2              2
#
#    summer_bronze summer_total  winter_participations  winter_gold  \
# 0              2            2                      0            0
# ...

# %%
sns.pairplot(data=df)

# %%
df['summer_gold'] = pd.to_numeric(df['summer_gold'], errors='coerce')

# %%
df['summer_gold'].dtypes
# Out:
# dtype('float64')

# %%
df['summer_total'] = pd.to_numeric(df['summer_total'], errors='coerce')
df['total_gold'] = pd.to_numeric(df['total_gold'], errors='coerce')
df['total_total '] = pd.to_numeric(df['total_total '], errors='coerce')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   countries              156 non-null    object
#  1   ioc_code               156 non-null    object
#  2   summer_participations  156 non-null    int64
#  3   summer_gold            155 non-null    float64
#  4   summer_silver          156 non-null    int64
#  5   summer_bronze          156 non-null    int64
#  6   summer_total           154 non-null    float64
#  7   winter_participations  156 non-null    int64
#  8   winter_gold            156 non-null    int64
#  9   winter_silver          156 non-null    int64
#  10  winter_bronze          156 non-null    int64
#  11  winter_total           156 non-null    int64
#  12  total_participation    156 non-null    int64
#  13  total_gold             155 non-null    float64
# ...

# %%
plt.figure(figsize=(10,5),dpi=150)
sns.heatmap(df.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
df.head(10)
# Out:
#     countries  ioc_code   summer_participations  summer_gold  summer_silver  \
# 0  Afghanistan     (AFG)                     15          0.0              0
# 1      Algeria     (ALG)                     14          5.0              4
# 2    Argentina     (ARG)                     25         21.0             26
# 3      Armenia     (ARM)                      7          2.0              8
# 4  Australasia     (ANZ)                      2          3.0              4
# 5    Australia     (AUS)                     27        164.0            173
# 6      Austria     (AUT)                     28         20.0             35
# 7   Azerbaijan     (AZE)                      7          7.0             14
# 8      Bahamas     (BAH)                     17          8.0              2
# 9      Bahrain     (BRN)                     10          2.0              2
#
#    summer_bronze  summer_total  winter_participations  winter_gold  \
# ...

# %%
df.shape
# Out:
# (156, 17)

# %%
s = df.xs('summer_gold', axis=1).sort_values(ascending=False)
s
# Out:
# 110    395.0
# 51     284.0
# 24     262.0
# 43     223.0
# 66     217.0
#        ...
# 115      0.0
# 116      0.0
# 117      0.0
# 0        0.0
# 144      NaN
# Name: summer_gold, Length: 156, dtype: float64

# %%
print(df[110:120])
# Out:
#                        countries  ioc_code   summer_participations  \
# 110                  Soviet Union     (URS)                      9
# 111                  Unified Team     (EUN)                      1
# 112  Olympic Athletes from Russia     (OAR)                      0
# 113                          ROC     (ROC)                       1
# 114                    San Marino     (SMR)                     15
# 115                  Saudi Arabia     (KSA)                     12
# 116                         Samoa     (SAM)                     10
# 117                       Senegal     (SEN)                     15
# 118                        Serbia     (SRB)                      5
# 119         Serbia and Montenegro     (SCG)                      3
#
#      summer_gold  summer_silver  summer_bronze  summer_total  \
# 110        395.0            319            296           NaN
# 111         45.0             38             29         112.0
# ...
